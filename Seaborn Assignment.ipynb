# %% [markdown]
# Que 1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.

# %% [markdown]
# Seaborn is a powerful Python data visualization library built on top of Matplotlib. It provides a high-level interface for creating informative and attractive statistical graphics. Seaborn offers a wide range of plot types to handle various data visualization tasks effectively.
#
# Commonly used plots that we can create using Seaborn and their uses:1.
#
# Scatter Plot: Scatter plots are used to visualize the relationship between two continuous variables. They help identify patterns, trends, and correlations between the variables. Seaborn's scatter plot can also incorporate additional information, such as color-coding points based on a third categorical variable, making it more informativ2.e.
#
# Bar Plot: Bar plots are effective for visualizing and comparing categorical data. They are used to display the distribution or count of categories and to compare the values of different categories. Seaborn's bar plot can also display confidence intervals, making it useful for presenting statistical summar3.ies.
#
# Box Plot (Box-and-Whisker Plot): Box plots provide a graphical summary of the distribution of numerical data. They show the median, quartiles, and the presence of outliers in the data. Seaborn's box plot is helpful for identifying data spread, skewness, and potential outliers across multiple groups or categ4.ories.
#
# Heatmap: Heatmaps are used to display a 2D representation of data where individual values are represented by colors. They are useful for visualizing the correlation matrix, showing patterns in large datasets, and identifying clusters or trends in the data. Seaborn's heatmap is especially popular for displaying correlation m5.atrices.
#
# Violin Plot: Violin plots combine aspects of a box plot and a kernel density plot. They provide a better representation of the data's distribution, including information about the density of values. Seaborn's violin plot is useful for comparing the distribution of data between different categories.

# %% [markdown]
# Que 2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x =
# "timepoint" and y = "signal" for different events and regions
#
# Note: timepoint, signal, event, and region are columns in the fmri dataset..

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
fmri_data = sns.load_dataset("fmri")

# %%
fmri_data.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x="timepoint" , y = "signal" ,data = fmri_data,hue="event",style="region")
plt.xlabel("Timepoint")
plt.ylabel("Signal")
plt.title("Line Plot")
plt.show()

# %% [markdown]
# Que 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x =
# 'pclass', y = 'age' and y = 'fare'.
# Note: pclass, age, and fare are columns in the titanic dataset.

# %%
titanic_data = sns.load_dataset("titanic")

# %%
titanic_data.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
#pclass vs age
sns.boxplot(x="pclass",y="age",data = titanic_data)
plt.subplot(1, 2, 1)
sns.boxplot(x='pclass', y='age', data=titanic_data)
plt.title('Box Plot: pclass vs. age')


#pclass vs. fare
plt.subplot(1, 2, 2)
sns.boxplot(x='pclass', y='fare', data=titanic_data)
plt.title('Box Plot: pclass vs. fare')

plt.show()

# %% [markdown]
# Que 4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue
# parameter for the 'cut' column of the diamonds dataset.

# %%
diamond_data = sns.load_dataset("diamonds")
diamond_data.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.histplot(data = diamond_data,x="price" , bins = 20,hue="cut")
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %% [markdown]
# Que 5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column
# of the iris dataset.

# %%
iris_data = sns.load_dataset("iris")

# %%
iris_data.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
sns.pairplot(data = iris_data,hue="species")
plt.show()

# %% [markdown]
# Que 6: Use the "flights" dataset from seaborn to plot a heatmap.

# %%
flight_data = sns.load_dataset("flights")

# %%
flight_data.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights_matrix = flight_data.pivot(index='month', columns='year', values='passengers')
sns.heatmap(flights_matrix,cmap='coolwarm', annot=True, fmt='d')
plt.title('Flights Heatmap')
plt.xlabel('Year')
plt.ylabel('Month')
plt.show()
